# %% [markdown]
# This is a short introduction into tensorflow. The goal for you is to be able to create your own neural networks at the end of this notebook. We are building a NN without any hidden layers.
#
# Please fill in the gaps.
#
# If you need any help, you can check out a toy example online:
#
# https://gist.github.com/hussius/1534135a419bb0b957b9
#
# As an additional task you can fix an error in the accuracy function.

# %% [markdown]
# # Import Libraries

# %%
from __future__ import division, print_function, unicode_literals

import tensorflow as tf
import numpy as np
import math
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# You might need to install the necessary libraries:
#
#     sudo pip install sklearn numpy matplotlib math

# %% [markdown]
# # Create Data

# %% [markdown]
# In the Toy example, we have a two-dimensional data set: $(x_1,x_2) \in [-1,1] \times [-1,1]$. We want to train the network to output 1, if $x_1 + x_2 >= 1$. Otherwise, the network should output 0. Therefore, we are going to create a dataset with the corresponding labels. We furthermore divide the data into a training set and a test set.
#
# In the following code, you do not need to do anything. However, you should understand what I am doing.

# %%
# Define total number of samples
tot_number_samples = 10000

# Create a dataset randomly and calculate the necessary labels
X = np.random.uniform(-1,1,size=(tot_number_samples,2))
y = (X[:,0] + X[:,1] >= 1).astype(np.double)*2-1

# Divide the dataset into a train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25) #25 % of data is in test set

#if you are unsure with train_test_split does, execute the next line
#help(train_test_split)

# %%
# Plot the test data in a graph for visualization
plt.figure(figsize=(8,8))

plt.scatter(X_test[:,0],X_test[:,1],c=y_test,cmap="RdYlGn")

plt.show()

# %% [markdown]
# # Build the Network

# %% [markdown]
# This is the only thing that you need to fill out in this task. Replace all the ... with a code.

# %%
n_input=2;
n_hidden=1;

# Create label placeholder
y = tf.placeholder(shape=[None], dtype=tf.float32, name="y")
print(y)
# Create the input layer
X      = tf.placeholder("float", shape=[None, 2]) # use tf.placeholder. Shape: [None,2]

# Create weights and biases (with random initial values)
W      = tf.Variable(tf.random_uniform(([2, 1]), -1.0 , 1.0)) # use tf.Variable. Shape: [2,1]
b      = tf.Variable(tf.zeros([1])) # use tf.Variable

# Create the output of the network
a      =   tf.squeeze( (tf.matmul(X,W) + b) , [1], name="a" )   # a = X*w + b
#a      = (tf.matmul(X,W) + b)
#a      =   (tf.matmul(X,W) + b)  # a = X*w + b
print(a)
y_pred = tf.nn.tanh(tf.squeeze(a), name="y_pred") # y_pred = tanh(a). Carefull: You need to remove one dimension from a using tf.squeeze, 
             # since we want y_pred to have the same shape as y
             # You can test the shape of 'a' and 'y' using print(a) and print(y)
# Out:
# Tensor("y:0", shape=(?,), dtype=float32)
# Tensor("a:0", shape=(?,), dtype=float32)

# %% [markdown]
# If everything has been done correctl, the following line shoult output something similar to:
#
# $\text{<tf.Tensor 'y_pred:0' shape=(?,) dtype=float32>}$

# %%
y_pred
# Out:
# <tf.Tensor 'y_pred:0' shape=<unknown> dtype=float32>

# %% [markdown]
# # Define Loss and Accuracy Function

# %%
loss               = tf.reduce_mean((y_pred-y)*(y_pred-y),name="loss")

y_pred_group       = tf.cast(y_pred>0.5,dtype=tf.float32,name="y_pred_group")
correct            = tf.equal(y_pred_group,y, name="correct")
accuracy           = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")


optimizer          = tf.train.AdamOptimizer()
training_optimizer = optimizer.minimize(loss, name="training_optimizer")

init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# Here, we are defining, how the network should be trained. Please look at the tensorflow website to understand, how this works.

# %% [markdown]
# # Train the Network

# %% [markdown]
# It is time to train the network now. The code has been adapted from here:
#
# https://github.com/ageron/handson-ml

# %%
n_epochs                = 100
batch_size              = 128

n_iterations_per_epoch  = y_train.shape[0] // batch_size
n_iterations_validation = y_test.shape[0] // batch_size
best_loss_val           = np.infty

checkpoint_path = "./Task_2_network"

with tf.Session() as sess:
    init.run()

    for epoch in range(n_epochs):
        for iteration in range(n_iterations_per_epoch):
            X_batch = X_train[iteration*batch_size:(iteration+1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration+1)*batch_size]
            
            # Run the training operation and measure the loss:
            _, loss_train = sess.run(
                [training_optimizer, loss],
                feed_dict={X: X_batch, y: y_batch })

        # At the end of each epoch,
        # measure the validation loss and accuracy:
        loss_vals = []
        acc_vals = []
        for iteration in range(n_iterations_validation):
            X_batch = X_test[iteration*batch_size:(iteration+1)*batch_size,:]
            y_batch = y_test[iteration*batch_size:(iteration+1)*batch_size]
            loss_val, acc_val = sess.run(
                [loss, accuracy],
                feed_dict={X: X_batch,y: y_batch})
            loss_vals.append(loss_val)
            acc_vals.append(acc_val)
        loss_val = np.mean(loss_vals)
        acc_val = np.mean(acc_vals)
        print("\rEpoch: {}  Val accuracy: {:.4f}%  Loss: {:.6f}{}".format(
            epoch+1, acc_val * 100, loss_val,
            " (improved)" if loss_val < best_loss_val else ""))

        # And save the model if it improved:
        if loss_val < best_loss_val:
            save_path = saver.save(sess, checkpoint_path)
            best_loss_val = loss_val
# Out:
# Epoch: 1  Val accuracy: 0.0000%  Loss: 1.306249 (improved)
# Epoch: 2  Val accuracy: 0.0000%  Loss: 1.204573 (improved)
# Epoch: 3  Val accuracy: 0.0000%  Loss: 1.108293 (improved)
# Epoch: 4  Val accuracy: 0.0000%  Loss: 1.018462 (improved)
# Epoch: 5  Val accuracy: 0.0000%  Loss: 0.935376 (improved)
# Epoch: 6  Val accuracy: 0.0000%  Loss: 0.858904 (improved)
# Epoch: 7  Val accuracy: 0.0000%  Loss: 0.788890 (improved)
# Epoch: 8  Val accuracy: 0.0000%  Loss: 0.725366 (improved)
# Epoch: 9  Val accuracy: 0.0000%  Loss: 0.668512 (improved)
# Epoch: 10  Val accuracy: 0.0000%  Loss: 0.618436 (improved)
# Epoch: 11  Val accuracy: 0.0000%  Loss: 0.574978 (improved)
# Epoch: 12  Val accuracy: 0.0000%  Loss: 0.537639 (improved)
# Epoch: 13  Val accuracy: 0.0000%  Loss: 0.505666 (improved)
# Epoch: 14  Val accuracy: 0.0000%  Loss: 0.478185 (improved)
# Epoch: 15  Val accuracy: 0.0000%  Loss: 0.454342 (improved)
# Epoch: 16  Val accuracy: 0.0000%  Loss: 0.433382 (improved)
# Epoch: 17  Val accuracy: 0.0000%  Loss: 0.414686 (improved)
# Epoch: 18  Val accuracy: 0.0000%  Loss: 0.397774 (improved)
# Epoch: 19  Val accuracy: 0.0000%  Loss: 0.382287 (improved)
# Epoch: 20  Val accuracy: 0.0000%  Loss: 0.367968 (improved)
# Epoch: 21  Val accuracy: 0.0000%  Loss: 0.354637 (improved)
# Epoch: 22  Val accuracy: 0.0000%  Loss: 0.342168 (improved)
# Epoch: 23  Val accuracy: 0.0000%  Loss: 0.330473 (improved)
# Epoch: 24  Val accuracy: 0.0000%  Loss: 0.319490 (improved)
# Epoch: 68  Val accuracy: 4.5641%  Loss: 0.138430 (improved)
# Epoch: 69  Val accuracy: 4.6464%  Loss: 0.136820 (improved)
# Epoch: 70  Val accuracy: 4.8109%  Loss: 0.135249 (improved)
# Epoch: 71  Val accuracy: 4.8931%  Loss: 0.133715 (improved)
# Epoch: 72  Val accuracy: 4.8931%  Loss: 0.132218 (improved)
# Epoch: 73  Val accuracy: 4.8931%  Loss: 0.130755 (improved)
# Epoch: 74  Val accuracy: 5.0164%  Loss: 0.129325 (improved)
# Epoch: 75  Val accuracy: 5.0987%  Loss: 0.127928 (improved)
# Epoch: 76  Val accuracy: 5.1398%  Loss: 0.126561 (improved)
# Epoch: 77  Val accuracy: 5.1809%  Loss: 0.125225 (improved)
# Epoch: 78  Val accuracy: 5.2220%  Loss: 0.123918 (improved)
# Epoch: 79  Val accuracy: 5.3454%  Loss: 0.122639 (improved)
# Epoch: 80  Val accuracy: 5.4276%  Loss: 0.121387 (improved)
# Epoch: 81  Val accuracy: 5.5099%  Loss: 0.120162 (improved)
# Epoch: 82  Val accuracy: 5.6332%  Loss: 0.118962 (improved)
# Epoch: 83  Val accuracy: 5.6332%  Loss: 0.117786 (improved)
# Epoch: 84  Val accuracy: 5.6332%  Loss: 0.116635 (improved)
# Epoch: 85  Val accuracy: 5.7566%  Loss: 0.115508 (improved)
# Epoch: 86  Val accuracy: 5.7566%  Loss: 0.114402 (improved)
# Epoch: 87  Val accuracy: 5.7977%  Loss: 0.113319 (improved)
# Epoch: 88  Val accuracy: 5.8388%  Loss: 0.112257 (improved)
# Epoch: 89  Val accuracy: 5.8799%  Loss: 0.111216 (improved)
# Epoch: 90  Val accuracy: 6.0444%  Loss: 0.110196 (improved)
# Epoch: 91  Val accuracy: 6.0444%  Loss: 0.109195 (improved)
# Epoch: 92  Val accuracy: 6.0444%  Loss: 0.108213 (improved)
# Epoch: 93  Val accuracy: 6.0444%  Loss: 0.107250 (improved)
# Epoch: 94  Val accuracy: 6.0444%  Loss: 0.106305 (improved)
# Epoch: 95  Val accuracy: 6.1678%  Loss: 0.105377 (improved)
# Epoch: 96  Val accuracy: 6.1678%  Loss: 0.104467 (improved)
# Epoch: 97  Val accuracy: 6.1678%  Loss: 0.103574 (improved)
# Epoch: 98  Val accuracy: 6.1678%  Loss: 0.102698 (improved)
# Epoch: 99  Val accuracy: 6.1678%  Loss: 0.101837 (improved)
# Epoch: 100  Val accuracy: 6.2089%  Loss: 0.100992 (improved)

# %% [markdown]
# If everything works correctly, the Loss function should be smaller than 0.1. TODO: The accuracy is not working properly. Can you fix it?

# %% [markdown]
# # Prediction

# %%
with tf.Session() as sess:
    saver.restore(sess, checkpoint_path)
    y_pred_value = sess.run(
            [y_pred],
            feed_dict={X: X_test,
                       y: np.zeros((X_test.shape[0]), dtype=np.float32)})
    y_pred_value = y_pred_value[0]
# Out:
# INFO:tensorflow:Restoring parameters from ./Task_2_network

# %%
# Plot the test data in a graph for visualization
plt.figure(figsize=(8,8))

plt.scatter(X_test[:,0],X_test[:,1],c=y_pred_value,cmap="RdYlGn")

plt.show()

# %%
# This command should output something very close to [-1,1]. Otherwise there was no convergence.
print([np.min(y_pred_value),np.max(y_pred_value)])
# Out:
# [-0.9999769, 0.946894]
